# %% [markdown]
# # Kernel Nadaraya-Watson Estimator

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from datetime import datetime
from copy import deepcopy
# utils for plotting
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.colors as colors
from joblib import Parallel, delayed
import pickle
import numpy as np

from functools import reduce
from operator import concat

from sklearn.metrics import mean_squared_error, accuracy_score

# utils for timing
from goodpoints.tictoc import tic, toc, TicToc
# utils for kernel ridge regression
from goodpoints.knw.util_estimators import get_estimator
# utils for evaluating kernels
# from goodpoints.krr.thin.util_k_mmd import kernel_eval, to_regression_kernel
# utils for generate samples from the data distribution
from goodpoints.krr.util_sample import get_Xy, ToyData , get_toy_dataset #, get_housing_dataset
# utils for dataset thinning
# from goodpoints.krr.thin.util_thin import sd_thin, kt_thin2
# # falkon baseline
# from goodpoints.krr.falkon.util_falkon_estimators import KernelRidgeFalkon

# %%
### Toy dataset parameters

n = 2**13

# X_name = 'unif-[0,1]' # 'unif-[0,1]'  # ['unif', 'unif-[0,1]', 'gauss', 'mog']
# f_name = 'dnc-paper' # 'dnc-paper' # ['sin', 'stair', 'quad', 'sum-gauss', 'sum-laplace', 'step', 'dnc-paper']

X_name = 'unif'
X_var = 1
f_name = 'sum-gauss'
noise = 0.1 # np.sqrt( 0.2 ) # in paper, variance is 1/5

d = 1
# M = 2
k = 8 # number of anchor points for sum-gauss and sum-laplace

### Regression parameters

# kernel = 'sobolev'  # ['sobolev', 'gauss', 'laplace']
# alpha_pow = -2/3  # gauss = -1, sobolev = -2/3

kernel = 'singular'
alpha_pow = -1

sigma =  0.25
alpha = np.power(float(n),alpha_pow)

### Experiment parameters

# varying_variable = 'kernel' # ['kernel', 'd', 'M']
n_repeats = 100
save = False
logn_lo = 8
logn_hi = 14
use_cross_validation = False
n_jobs = 1
# method = 'st'

### Thinning parameters

m = None # Thinned dataset will have size n/2**m
# m=9

# %%
# Determine auxiliary parameters
task = 'regression'
refit = 'neg_mean_squared_error'
postprocess = None

filename = '_'.join([X_name, f_name, f'k={k}', f'noise={noise}'])
print(filename)

baseline_loss = noise**2
print(f'baseline loss: {baseline_loss}')
# Out:
# unif_sum-gauss_k=8_noise=0.1
# baseline loss: 0.010000000000000002

# %%
toy_data_noise = ToyData(X_name, f_name, 
                        #  X_var=X_var, 
                         noise=noise, 
                        d=d, 
                        # M=M, 
                        k=k)

X_train, y_train = toy_data_noise.sample(n)
X_test, y_test = toy_data_noise.sample(10000)
# validation set used for cross validation
X_val, y_val = toy_data_noise.sample(10000)

# no noise version for plotting purposes
toy_data_no_noise = ToyData(X_name, f_name, noise=0, 
                    d=d, k=k)
X_no_noise, y_no_noise = toy_data_no_noise.sample(n)

print(X_train.shape, y_train.shape)
# Out:
# (8192, 1) (8192,)

# %%
def trace_Xy(X, y, name=None, color=None, alpha=0.5):
    d = X.shape[-1]

    if d==1:
        return go.Scatter(
            x=X.squeeze(), 
            y=y, 
            mode='markers',
            name=name,
            opacity=alpha,
            marker=dict(
                color=color,
            )
        )

    elif d==2:
        x1,x2 = X[:,0], X[:,1]
        return go.Scatter3d(x=x1, y=x2, z=y, mode='markers', name=name, marker=dict(
            symbol='circle',
            opacity=alpha,
            color=color,
            size=2,
            # line=dict(width=1),
        ))

    else:
        print(f"cannot plot data with dimension {d}")

# %%
fig = go.Figure(data=[
    trace_Xy(X_train, y_train, name='train'),
    # trace_Xy(X_test, y_test, name='test'),
    trace_Xy(X_no_noise, y_no_noise, name='no noise', color='black'),
])
fig.update_layout(
    title=f'X={X_name}, f={f_name}, std[f]={np.std(y_train):.4f}', #, hnorm[f]={hnorm(k):.4f}',
    height=400,
    width=800,
)
fig.show()
# save fig
if save: fig.write_image(f"figures/{filename}_function.png")

# %% [markdown]
# ## KNW Full

# %%
knw_full = get_estimator(
    task, 
    'full',
    kernel='box', 
    sigma=sigma,
)

# %%
knw_full
# Out:
# KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)

# %%
knw_full.fit(X_train, y_train)
# Out:
# KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)

# %%
pred_full = knw_full.predict(X_test)
train_pred_full = knw_full.predict(X_train)

print('train MSE:', mean_squared_error(y_train, train_pred_full))
print('MSE:', mean_squared_error(y_test, pred_full))
# Out:
# train MSE: 0.0
# MSE: 0.011173282255553078

# %%
fig = go.Figure(data=[
    # trace_Xy(krr_sd_thin.X_fit_, krr_sd_thin.y_fit_, name='train coreset', alpha=1),
    trace_Xy(X_test, y_test, name='test', alpha=0.1),
    trace_Xy(X_test, pred_full, name='pred', alpha=0.4)
])
fig.update_layout(
    title='full',
    height=400,
    width=800,
)
fig.show()
# save fig
if save: fig.write_image(f"figures/{filename}_full.png")

# %% [markdown]
# ## KNW ST

# %%
knw_st = get_estimator(
    task, 
    'st',
    kernel=kernel, 
    sigma=sigma,
)

# %%
knw_st
# Out:
# KernelNadarayaWatsonSTRegressor(kernel='singular', sigma=0.25)

# %%
knw_st.fit(X_train, y_train)

# %%
# %%time
pred_st = knw_st.predict(X_test)
train_pred_st = knw_st.predict(X_train)

print('train MSE:', mean_squared_error(y_train, train_pred_st))
print('MSE:', mean_squared_error(y_test, pred_st))
# Out:
# train MSE: 0.012338862617609563
# MSE: 0.01295145938382656
# CPU times: user 214 ms, sys: 353 ms, total: 566 ms
# Wall time: 104 ms

# %%
fig = go.Figure(data=[
    # trace_Xy(krr_sd_thin.X_fit_, krr_sd_thin.y_fit_, name='train coreset', alpha=1),
    trace_Xy(X_test, y_test, name='test', alpha=0.1),
    trace_Xy(X_test, pred_st, name='pred', alpha=0.4)
])
fig.update_layout(
    title='st',
    height=400,
    width=800,
)
fig.show()
# save fig
if save: fig.write_image(f"figures/{filename}_st.png")

# %% [markdown]
# ## KNW KT

# %%
# knw_kt = get_estimator(
#     task, 
#     'kt',
#     kernel=kernel, 
#     sigma=sigma,
# )

# %%
# knw_kt

# %%
# knw_kt.fit(X_train, y_train)

# %%
# knw_kt.y_fit_

# %%
# %%time
# pred_kt = knw_kt.predict(X_test)
# train_pred_kt = knw_kt.predict(X_train)

# %%
# print('train MSE:', mean_squared_error(y_train, train_pred_kt))
# # print('MSE:', mean_squared_error(y_test, pred_kt))

# %%
# fig = go.Figure(data=[
#     # trace_Xy(krr_sd_thin.X_fit_, krr_sd_thin.y_fit_, name='train coreset', alpha=1),
#     trace_Xy(X_test, y_test, name='test', alpha=0.1),
#     trace_Xy(X_test, pred_kt, name='pred', alpha=0.4)
# ])
# fig.update_layout(
#     title='kt',
#     height=400,
#     width=800,
# )
# fig.show()
# # save fig
# if save: fig.write_image(f"figures/{filename}_kt.png")

# %% [markdown]
# ## Experiment

# %%
from sklearn.model_selection import GridSearchCV, RepeatedKFold

# %%
varying_variable = 'kernel'
varying_variable_values = ['gauss', 'laplace', 'singular', 'box']

# %%
print('Running experiment with varying variable:', varying_variable)
print('taking values:', varying_variable_values)
# Out:
# Running experiment with varying variable: kernel
# taking values: ['gauss', 'laplace', 'singular', 'box']

# %%
# # Default param grid to search for each model
default_param_grid = {
    "sigma" :   [sigma,],
    # "alpha" :   [1e1, 1e-0, 1e-1, 1e-2, 1e-3, 1e-4],

    # "sigma" :   1/np.sqrt(2*np.array([0.5, 1., 2, 5.])),
    # "alpha" :   [0.01, 0.02]
}
falkon_param_grid = {
    "sigma" :   [sigma,],
    # "alpha" :   [1e-4, 1e-5,1e-6, 1e-7, 0],
}


# Model constructors and data size for each model
# We allow for different data sizes to avoid running Full KR on large datasets
model_configs = {
    # 'full' : {
    #     'logn' : np.arange(logn_lo, logn_hi, 2),
    #     # 'logn' : np.arange(8, 13, 2),
    #     'kwargs': {
    #         'postprocess' : postprocess,
    #         # 'alpha' : alpha,
    #         # 'sigma' : sigma,
    #     },
    #     'param_grid' : default_param_grid,
    # },
    
}
for sigma in np.arange(0.05, 0.45, 0.05):
    model_configs[f'full_{sigma}'] = {
        'logn' : np.arange(logn_lo, logn_hi, 1),
        'kwargs' : {
            'postprocess' : postprocess,
            'sigma' : sigma,
        },
        # 'param_grid' : default_param_grid,
    }

# %%
model_configs
# Out:
# {'full_0.05': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.05}},
#  'full_0.1': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.1}},
#  'full_0.15000000000000002': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.15000000000000002}},
#  'full_0.2': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.2}},
#  'full_0.25': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.25}},
#  'full_0.30000000000000004': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.30000000000000004}},
#  'full_0.35000000000000003': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.35000000000000003}},
#  'full_0.4': {'logn': array([ 8,  9, 10, 11, 12, 13]),
#   'kwargs': {'postprocess': None, 'sigma': 0.4}}}

# %%
# Run experiment (depending on experiment_type)

results = []

i = 0
for name, config in model_configs.items():
    for logn in config['logn']:

        for v in varying_variable_values:
            kwargs = deepcopy(config['kwargs'])
            kwargs[varying_variable] = v

            model_name = f"{name}_{v}"
            trials = 1

            X, y = get_toy_dataset(
                X_name=X_name,
                f_name=f_name,
                n=2**logn,
                # X_var=X_var,
                d=kwargs['d'] if 'd' in kwargs else d,
                noise=noise,
                # M=kwargs['M'] if 'M' in kwargs else M,
                k=k,
            )
            
            # Set kernel, alpha, sigma params
            if 'kernel' not in kwargs:
                kwargs['kernel'] = kernel
            
            model = get_estimator(task, name=name, **kwargs)
            if model is None: continue
            # if kwargs['m'] > logn: continue

            print(f'i={i+1}: logn={logn}, model={model}')

            # STEP 2: Get optimal parameters through grid search
            # NOTE: we do something slightly better than k-fold cross validation.
            # Namely, we are trying to get rid of randomness in the Kernel Thinning (or Standard Thinning) routine,
            # but if we did 100-fold CV, then the validation set would be 1% of the data
            # (which is too small to get a good estimate of the validation score).
            # Instead we use the same train-val split for each parameter setting and repeat `trials` times
            if use_cross_validation:
                X_concat, y_concat = np.concatenate([X, X_val]), np.concatenate([y, y_val])
                split = [(np.arange(len(X)), np.arange(len(X), len(X)+len(X_val))) for _ in range(trials)]
                grid_search = GridSearchCV(
                    estimator=model,
                    param_grid=config['param_grid'],
                    return_train_score=True,
                    cv=split,
                    scoring=refit,
                    refit=False,
                    n_jobs=n_jobs,
                ).fit(X_concat, y_concat)
                # get validation scores
                cv_results = pd.DataFrame(grid_search.cv_results_)
                val_scores = []
                for i in range(trials):
                    val_scores.append( cv_results.iloc[grid_search.best_index_][f'split{i}_test_score'] )

                # get optimal parameters
                best_params = grid_search.best_params_
            else:
                # Dummy values
                val_scores = [1,] * trials
                
                best_params = {
                    # 'sigma' : sigma,
                    # 'alpha' : alpha, # * (len(X_train)**(1/4) if name in ['st', 'kt'] else 1),
                }    

            def run():
                # print(f"best params: {best_params}")            
                best_model = get_estimator(task, name=name, 
                                        # sigma=best_params['sigma'],
                                        #    alpha=best_params['alpha'],
                                        **kwargs)
                best_model.fit(X, y)
                return best_model.predict(X_test).squeeze()

            parallel = Parallel(n_jobs=n_jobs)
            output_generator = parallel(delayed(run)() for _ in range(trials))

            mean_scores = []
            for test_pred in output_generator:
                if refit == 'neg_mean_squared_error':
                    test_scores = mean_squared_error(y_test, test_pred)
                elif refit == 'accuracy':
                    test_scores = accuracy_score(y_test, test_pred)
                else:
                    raise ValueError(f"invalid refit metric: {refit}")

                mean_scores.append( np.mean(test_scores) )

            results.append({
                "logn": logn, 
                "model": model_name, 
                "cv_results": pd.DataFrame(grid_search.cv_results_) if use_cross_validation else None,
                "best_index_" : grid_search.best_index_ if use_cross_validation else 0,
                "mean_scores" : mean_scores,
                # "std_score" : np.std(mean_scores),
            })

            if save:
                with open(f"results/{filename}.pkl", 'wb') as f:
                    pickle.dump(results, f)

            i += 1
# Out:
# sampling dataset with params ToyData(X_name=unif, f_name=sum-gauss, X_var=1, d=1, noise=0.1, M=4, k=8)
# i=1: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.05)
# i=2: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.05)
# i=3: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.05)
# i=4: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.05)
# sampling dataset with params ToyData(X_name=unif, f_name=sum-gauss, X_var=1, d=1, noise=0.1, M=4, k=8)
# i=5: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.05)
# i=6: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.05)
# i=7: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.05)
# i=8: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.05)
# sampling dataset with params ToyData(X_name=unif, f_name=sum-gauss, X_var=1, d=1, noise=0.1, M=4, k=8)
# i=9: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.05)
# i=10: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.05)
# i=11: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.05)
# i=12: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.05)
# sampling dataset with params ToyData(X_name=unif, f_name=sum-gauss, X_var=1, d=1, noise=0.1, M=4, k=8)
# i=13: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.05)
# i=14: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.05)
# i=15: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.05)
# i=16: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.05)
# sampling dataset with params ToyData(X_name=unif, f_name=sum-gauss, X_var=1, d=1, noise=0.1, M=4, k=8)
# i=17: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.05)
# i=18: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.05)
# i=19: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.05)
# i=20: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.05)
# sampling dataset with params ToyData(X_name=unif, f_name=sum-gauss, X_var=1, d=1, noise=0.1, M=4, k=8)
# i=21: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.05)
# i=22: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.05)
# i=23: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.05)
# i=24: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.05)
# i=25: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.1)
# i=26: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.1)
# i=27: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.1)
# i=28: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.1)
# i=29: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.1)
# i=30: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.1)
# i=31: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.1)
# i=32: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.1)
# i=33: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.1)
# i=34: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.1)
# i=35: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.1)
# i=36: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.1)
# i=37: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.1)
# i=38: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.1)
# i=39: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.1)
# i=40: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.1)
# i=41: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.1)
# i=42: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.1)
# i=43: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.1)
# i=44: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.1)
# i=45: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.1)
# i=46: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.1)
# i=47: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.1)
# i=48: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.1)
# i=49: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.15000000000000002)
# i=50: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.15000000000000002)
# i=51: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.15000000000000002)
# i=52: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.15000000000000002)
# i=53: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.15000000000000002)
# i=54: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.15000000000000002)
# i=55: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.15000000000000002)
# i=56: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.15000000000000002)
# i=57: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.15000000000000002)
# i=58: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.15000000000000002)
# i=59: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.15000000000000002)
# i=60: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.15000000000000002)
# i=61: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.15000000000000002)
# i=62: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.15000000000000002)
# i=63: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.15000000000000002)
# i=64: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.15000000000000002)
# i=65: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.15000000000000002)
# i=66: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.15000000000000002)
# i=67: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.15000000000000002)
# i=68: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.15000000000000002)
# i=69: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.15000000000000002)
# i=70: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.15000000000000002)
# i=71: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.15000000000000002)
# i=72: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.15000000000000002)
# i=73: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.2)
# i=74: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.2)
# i=75: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.2)
# i=76: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.2)
# i=77: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.2)
# i=78: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.2)
# i=79: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.2)
# i=80: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.2)
# i=81: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.2)
# i=82: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.2)
# i=83: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.2)
# i=84: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.2)
# i=85: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.2)
# i=86: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.2)
# i=87: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.2)
# i=88: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.2)
# i=89: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.2)
# i=90: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.2)
# i=91: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.2)
# i=92: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.2)
# i=93: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.2)
# i=94: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.2)
# i=95: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.2)
# i=96: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.2)
# i=97: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.25)
# i=98: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.25)
# i=99: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.25)
# i=100: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)
# i=101: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.25)
# i=102: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.25)
# i=103: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.25)
# i=104: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)
# i=105: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.25)
# i=106: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.25)
# i=107: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.25)
# i=108: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)
# i=109: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.25)
# i=110: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.25)
# i=111: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.25)
# i=112: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)
# i=113: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.25)
# i=114: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.25)
# i=115: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.25)
# i=116: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)
# i=117: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.25)
# i=118: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.25)
# i=119: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.25)
# i=120: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.25)
# i=121: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.30000000000000004)
# i=122: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.30000000000000004)
# i=123: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.30000000000000004)
# i=124: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.30000000000000004)
# i=125: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.30000000000000004)
# i=126: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.30000000000000004)
# i=127: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.30000000000000004)
# i=128: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.30000000000000004)
# i=129: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.30000000000000004)
# i=130: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.30000000000000004)
# i=131: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.30000000000000004)
# i=132: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.30000000000000004)
# i=133: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.30000000000000004)
# i=134: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.30000000000000004)
# i=135: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.30000000000000004)
# i=136: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.30000000000000004)
# i=137: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.30000000000000004)
# i=138: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.30000000000000004)
# i=139: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.30000000000000004)
# i=140: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.30000000000000004)
# i=141: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.30000000000000004)
# i=142: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.30000000000000004)
# i=143: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.30000000000000004)
# i=144: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.30000000000000004)
# i=145: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.35000000000000003)
# i=146: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.35000000000000003)
# i=147: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.35000000000000003)
# i=148: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.35000000000000003)
# i=149: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.35000000000000003)
# i=150: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.35000000000000003)
# i=151: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.35000000000000003)
# i=152: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.35000000000000003)
# i=153: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.35000000000000003)
# i=154: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.35000000000000003)
# i=155: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.35000000000000003)
# i=156: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.35000000000000003)
# i=157: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.35000000000000003)
# i=158: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.35000000000000003)
# i=159: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.35000000000000003)
# i=160: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.35000000000000003)
# i=161: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.35000000000000003)
# i=162: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.35000000000000003)
# i=163: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.35000000000000003)
# i=164: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.35000000000000003)
# i=165: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.35000000000000003)
# i=166: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.35000000000000003)
# i=167: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.35000000000000003)
# i=168: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.35000000000000003)
# i=169: logn=8, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.4)
# i=170: logn=8, model=KernelNadarayaWatsonRegressor(sigma=0.4)
# i=171: logn=8, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.4)
# i=172: logn=8, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.4)
# i=173: logn=9, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.4)
# i=174: logn=9, model=KernelNadarayaWatsonRegressor(sigma=0.4)
# i=175: logn=9, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.4)
# i=176: logn=9, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.4)
# i=177: logn=10, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.4)
# i=178: logn=10, model=KernelNadarayaWatsonRegressor(sigma=0.4)
# i=179: logn=10, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.4)
# i=180: logn=10, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.4)
# i=181: logn=11, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.4)
# i=182: logn=11, model=KernelNadarayaWatsonRegressor(sigma=0.4)
# i=183: logn=11, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.4)
# i=184: logn=11, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.4)
# i=185: logn=12, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.4)
# i=186: logn=12, model=KernelNadarayaWatsonRegressor(sigma=0.4)
# i=187: logn=12, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.4)
# i=188: logn=12, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.4)
# i=189: logn=13, model=KernelNadarayaWatsonRegressor(kernel='gauss', sigma=0.4)
# i=190: logn=13, model=KernelNadarayaWatsonRegressor(sigma=0.4)
# i=191: logn=13, model=KernelNadarayaWatsonRegressor(kernel='singular', sigma=0.4)
# i=192: logn=13, model=KernelNadarayaWatsonRegressor(kernel='box', sigma=0.4)

# %%
results
# Out:
# [{'logn': 8,
#   'model': 'full_0.05_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010865750242829498]},
#  {'logn': 8,
#   'model': 'full_0.05_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01096672669810978]},
#  {'logn': 8,
#   'model': 'full_0.05_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014231075771837362]},
#  {'logn': 8,
#   'model': 'full_0.05_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012020346775352143]},
#  {'logn': 9,
#   'model': 'full_0.05_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010582393592570858]},
#  {'logn': 9,
#   'model': 'full_0.05_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01069707629131954]},
#  {'logn': 9,
#   'model': 'full_0.05_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012497833569027514]},
#  {'logn': 9,
#   'model': 'full_0.05_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011245774863167617]},
#  {'logn': 10,
#   'model': 'full_0.05_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010237720660238727]},
#  {'logn': 10,
#   'model': 'full_0.05_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010326941002646086]},
#  {'logn': 10,
#   'model': 'full_0.05_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01165086548173627]},
#  {'logn': 10,
#   'model': 'full_0.05_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010715728560243224]},
#  {'logn': 11,
#   'model': 'full_0.05_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010174928894189802]},
#  {'logn': 11,
#   'model': 'full_0.05_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010222426997310801]},
#  {'logn': 11,
#   'model': 'full_0.05_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011065303333606766]},
#  {'logn': 11,
#   'model': 'full_0.05_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010506908686297382]},
#  {'logn': 12,
#   'model': 'full_0.05_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010166783604713908]},
#  {'logn': 12,
#   'model': 'full_0.05_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010311160151161469]},
#  {'logn': 12,
#   'model': 'full_0.05_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010636601646592561]},
#  {'logn': 12,
#   'model': 'full_0.05_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010302388817943634]},
#  {'logn': 13,
#   'model': 'full_0.05_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01010840693678836]},
#  {'logn': 13,
#   'model': 'full_0.05_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010222458056685969]},
#  {'logn': 13,
#   'model': 'full_0.05_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010332904835505563]},
#  {'logn': 13,
#   'model': 'full_0.05_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010163616232863888]},
#  {'logn': 8,
#   'model': 'full_0.1_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011291765447478484]},
#  {'logn': 8,
#   'model': 'full_0.1_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012804769872488754]},
#  {'logn': 8,
#   'model': 'full_0.1_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012606097874530164]},
#  {'logn': 8,
#   'model': 'full_0.1_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011319039164360728]},
#  {'logn': 9,
#   'model': 'full_0.1_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011157042826708565]},
#  {'logn': 9,
#   'model': 'full_0.1_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012903552475253514]},
#  {'logn': 9,
#   'model': 'full_0.1_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011582816750723321]},
#  {'logn': 9,
#   'model': 'full_0.1_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010796843497223525]},
#  {'logn': 10,
#   'model': 'full_0.1_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01073562699812153]},
#  {'logn': 10,
#   'model': 'full_0.1_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012278331307077813]},
#  {'logn': 10,
#   'model': 'full_0.1_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010977537059671487]},
#  {'logn': 10,
#   'model': 'full_0.1_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01042110960677453]},
#  {'logn': 11,
#   'model': 'full_0.1_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010571361984115225]},
#  {'logn': 11,
#   'model': 'full_0.1_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012002377973245071]},
#  {'logn': 11,
#   'model': 'full_0.1_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01067030730225079]},
#  {'logn': 11,
#   'model': 'full_0.1_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010314530687575948]},
#  {'logn': 12,
#   'model': 'full_0.1_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010862429011788221]},
#  {'logn': 12,
#   'model': 'full_0.1_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012519802256215818]},
#  {'logn': 12,
#   'model': 'full_0.1_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010404496564928855]},
#  {'logn': 12,
#   'model': 'full_0.1_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010247360600395354]},
#  {'logn': 13,
#   'model': 'full_0.1_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010738775919469057]},
#  {'logn': 13,
#   'model': 'full_0.1_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01231840121670397]},
#  {'logn': 13,
#   'model': 'full_0.1_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01021431733463294]},
#  {'logn': 13,
#   'model': 'full_0.1_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010144282451013155]},
#  {'logn': 8,
#   'model': 'full_0.15000000000000002_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01379419617761711]},
#  {'logn': 8,
#   'model': 'full_0.15000000000000002_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.019312262260772973]},
#  {'logn': 8,
#   'model': 'full_0.15000000000000002_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012000038323824035]},
#  {'logn': 8,
#   'model': 'full_0.15000000000000002_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01123094226507021]},
#  {'logn': 9,
#   'model': 'full_0.15000000000000002_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014009075569140845]},
#  {'logn': 9,
#   'model': 'full_0.15000000000000002_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.019899168116807038]},
#  {'logn': 9,
#   'model': 'full_0.15000000000000002_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011214608508568088]},
#  {'logn': 9,
#   'model': 'full_0.15000000000000002_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010772379313297758]},
#  {'logn': 10,
#   'model': 'full_0.15000000000000002_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.013298506053730404]},
#  {'logn': 10,
#   'model': 'full_0.15000000000000002_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.018907009162650583]},
#  {'logn': 10,
#   'model': 'full_0.15000000000000002_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010715028916429637]},
#  {'logn': 10,
#   'model': 'full_0.15000000000000002_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010418135246031692]},
#  {'logn': 11,
#   'model': 'full_0.15000000000000002_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012987530672234836]},
#  {'logn': 11,
#   'model': 'full_0.15000000000000002_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01846797800241299]},
#  {'logn': 11,
#   'model': 'full_0.15000000000000002_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010506840549577632]},
#  {'logn': 11,
#   'model': 'full_0.15000000000000002_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01028766682429166]},
#  {'logn': 12,
#   'model': 'full_0.15000000000000002_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01360696627705071]},
#  {'logn': 12,
#   'model': 'full_0.15000000000000002_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01940551737149764]},
#  {'logn': 12,
#   'model': 'full_0.15000000000000002_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01032634508219911]},
#  {'logn': 12,
#   'model': 'full_0.15000000000000002_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010357979457850204]},
#  {'logn': 13,
#   'model': 'full_0.15000000000000002_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.013388698701675134]},
#  {'logn': 13,
#   'model': 'full_0.15000000000000002_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.019083868649550195]},
#  {'logn': 13,
#   'model': 'full_0.15000000000000002_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010176477855578374]},
#  {'logn': 13,
#   'model': 'full_0.15000000000000002_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010242182200072005]},
#  {'logn': 8,
#   'model': 'full_0.2_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.020091095440267184]},
#  {'logn': 8,
#   'model': 'full_0.2_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.031479419874483605]},
#  {'logn': 8,
#   'model': 'full_0.2_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011694625170432175]},
#  {'logn': 8,
#   'model': 'full_0.2_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011415781546713652]},
#  {'logn': 9,
#   'model': 'full_0.2_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.020752478753168067]},
#  {'logn': 9,
#   'model': 'full_0.2_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.0325580201770713]},
#  {'logn': 9,
#   'model': 'full_0.2_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011025304393617636]},
#  {'logn': 9,
#   'model': 'full_0.2_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011053382399300602]},
#  {'logn': 10,
#   'model': 'full_0.2_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01972265551425021]},
#  {'logn': 10,
#   'model': 'full_0.2_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03127705973439198]},
#  {'logn': 10,
#   'model': 'full_0.2_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010585853249909556]},
#  {'logn': 10,
#   'model': 'full_0.2_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010673416243533546]},
#  {'logn': 11,
#   'model': 'full_0.2_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01927876043982042]},
#  {'logn': 11,
#   'model': 'full_0.2_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03073161946163531]},
#  {'logn': 11,
#   'model': 'full_0.2_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010413740507383798]},
#  {'logn': 11,
#   'model': 'full_0.2_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01047425605457247]},
#  {'logn': 12,
#   'model': 'full_0.2_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.020239932999260458]},
#  {'logn': 12,
#   'model': 'full_0.2_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03201386562587288]},
#  {'logn': 12,
#   'model': 'full_0.2_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010304125811662129]},
#  {'logn': 12,
#   'model': 'full_0.2_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010686835815993653]},
#  {'logn': 13,
#   'model': 'full_0.2_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.019922489753871012]},
#  {'logn': 13,
#   'model': 'full_0.2_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03161584541133268]},
#  {'logn': 13,
#   'model': 'full_0.2_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01016957451295806]},
#  {'logn': 13,
#   'model': 'full_0.2_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010540533567490977]},
#  {'logn': 8,
#   'model': 'full_0.25_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03168726456853112]},
#  {'logn': 8,
#   'model': 'full_0.25_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.0489436223040908]},
#  {'logn': 8,
#   'model': 'full_0.25_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011534950273894479]},
#  {'logn': 8,
#   'model': 'full_0.25_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011980606945774923]},
#  {'logn': 9,
#   'model': 'full_0.25_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.032816592967002664]},
#  {'logn': 9,
#   'model': 'full_0.25_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.05046999540032701]},
#  {'logn': 9,
#   'model': 'full_0.25_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010937571106247197]},
#  {'logn': 9,
#   'model': 'full_0.25_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01176434968003758]},
#  {'logn': 10,
#   'model': 'full_0.25_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03153726203489333]},
#  {'logn': 10,
#   'model': 'full_0.25_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.049011550035212084]},
#  {'logn': 10,
#   'model': 'full_0.25_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01052881116550976]},
#  {'logn': 10,
#   'model': 'full_0.25_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011269223846414392]},
#  {'logn': 11,
#   'model': 'full_0.25_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03099638768132635]},
#  {'logn': 11,
#   'model': 'full_0.25_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.04841043482911593]},
#  {'logn': 11,
#   'model': 'full_0.25_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010364033947653093]},
#  {'logn': 11,
#   'model': 'full_0.25_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011013429583170833]},
#  {'logn': 12,
#   'model': 'full_0.25_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.032267499950278604]},
#  {'logn': 12,
#   'model': 'full_0.25_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.049947653831606154]},
#  {'logn': 12,
#   'model': 'full_0.25_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010321736633526155]},
#  {'logn': 12,
#   'model': 'full_0.25_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011364453441807648]},
#  {'logn': 13,
#   'model': 'full_0.25_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.03186967062149293]},
#  {'logn': 13,
#   'model': 'full_0.25_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.04952289913294076]},
#  {'logn': 13,
#   'model': 'full_0.25_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010189859972087736]},
#  {'logn': 13,
#   'model': 'full_0.25_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011181719636351187]},
#  {'logn': 8,
#   'model': 'full_0.30000000000000004_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.04908498616333561]},
#  {'logn': 8,
#   'model': 'full_0.30000000000000004_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07077351007517016]},
#  {'logn': 8,
#   'model': 'full_0.30000000000000004_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011468562351382083]},
#  {'logn': 8,
#   'model': 'full_0.30000000000000004_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.013084605920727384]},
#  {'logn': 9,
#   'model': 'full_0.30000000000000004_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.05065750718202481]},
#  {'logn': 9,
#   'model': 'full_0.30000000000000004_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07269695927122004]},
#  {'logn': 9,
#   'model': 'full_0.30000000000000004_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010931046826212954]},
#  {'logn': 9,
#   'model': 'full_0.30000000000000004_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.013012475671772964]},
#  {'logn': 10,
#   'model': 'full_0.30000000000000004_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.04923902645482632]},
#  {'logn': 10,
#   'model': 'full_0.30000000000000004_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07114982968524243]},
#  {'logn': 10,
#   'model': 'full_0.30000000000000004_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01052802564145752]},
#  {'logn': 10,
#   'model': 'full_0.30000000000000004_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01237739525448554]},
#  {'logn': 11,
#   'model': 'full_0.30000000000000004_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.04864931867850243]},
#  {'logn': 11,
#   'model': 'full_0.30000000000000004_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07052824612873584]},
#  {'logn': 11,
#   'model': 'full_0.30000000000000004_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010356695473757524]},
#  {'logn': 11,
#   'model': 'full_0.30000000000000004_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012062158692738625]},
#  {'logn': 12,
#   'model': 'full_0.30000000000000004_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.0501554307559516]},
#  {'logn': 12,
#   'model': 'full_0.30000000000000004_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07224263664925057]},
#  {'logn': 12,
#   'model': 'full_0.30000000000000004_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010380430962967875]},
#  {'logn': 12,
#   'model': 'full_0.30000000000000004_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.012553864992167783]},
#  {'logn': 13,
#   'model': 'full_0.30000000000000004_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.04972137196954265]},
#  {'logn': 13,
#   'model': 'full_0.30000000000000004_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.0718273337834854]},
#  {'logn': 13,
#   'model': 'full_0.30000000000000004_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01024387942399883]},
#  {'logn': 13,
#   'model': 'full_0.30000000000000004_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01233118656714606]},
#  {'logn': 8,
#   'model': 'full_0.35000000000000003_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.0717942023305239]},
#  {'logn': 8,
#   'model': 'full_0.35000000000000003_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09588249348444794]},
#  {'logn': 8,
#   'model': 'full_0.35000000000000003_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011480458065862589]},
#  {'logn': 8,
#   'model': 'full_0.35000000000000003_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014867421821946687]},
#  {'logn': 9,
#   'model': 'full_0.35000000000000003_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07375596811807344]},
#  {'logn': 9,
#   'model': 'full_0.35000000000000003_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09815371569825283]},
#  {'logn': 9,
#   'model': 'full_0.35000000000000003_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.01100182484313346]},
#  {'logn': 9,
#   'model': 'full_0.35000000000000003_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014974318971888138]},
#  {'logn': 10,
#   'model': 'full_0.35000000000000003_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07230532925739379]},
#  {'logn': 10,
#   'model': 'full_0.35000000000000003_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09657680310231422]},
#  {'logn': 10,
#   'model': 'full_0.35000000000000003_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010584301958706162]},
#  {'logn': 10,
#   'model': 'full_0.35000000000000003_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014174699138811505]},
#  {'logn': 11,
#   'model': 'full_0.35000000000000003_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07171504214193979]},
#  {'logn': 11,
#   'model': 'full_0.35000000000000003_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09595697709267986]},
#  {'logn': 11,
#   'model': 'full_0.35000000000000003_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010398273182175215]},
#  {'logn': 11,
#   'model': 'full_0.35000000000000003_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.013797545551211692]},
#  {'logn': 12,
#   'model': 'full_0.35000000000000003_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07336589531473581]},
#  {'logn': 12,
#   'model': 'full_0.35000000000000003_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09778698676158727]},
#  {'logn': 12,
#   'model': 'full_0.35000000000000003_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010487680624652834]},
#  {'logn': 12,
#   'model': 'full_0.35000000000000003_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014436533904960927]},
#  {'logn': 13,
#   'model': 'full_0.35000000000000003_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.07295004225504848]},
#  {'logn': 13,
#   'model': 'full_0.35000000000000003_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09740290819231977]},
#  {'logn': 13,
#   'model': 'full_0.35000000000000003_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010341846653284595]},
#  {'logn': 13,
#   'model': 'full_0.35000000000000003_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.014168973115470234]},
#  {'logn': 8,
#   'model': 'full_0.4_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09878670988721334]},
#  {'logn': 8,
#   'model': 'full_0.4_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.12318033674241204]},
#  {'logn': 8,
#   'model': 'full_0.4_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011569408335143532]},
#  {'logn': 8,
#   'model': 'full_0.4_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.017538350384135214]},
#  {'logn': 9,
#   'model': 'full_0.4_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.10107755286594333]},
#  {'logn': 9,
#   'model': 'full_0.4_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.12575090052444995]},
#  {'logn': 9,
#   'model': 'full_0.4_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.011151120350124314]},
#  {'logn': 9,
#   'model': 'full_0.4_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.017806716301494843]},
#  {'logn': 10,
#   'model': 'full_0.4_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09967314590487115]},
#  {'logn': 10,
#   'model': 'full_0.4_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.12418018340587834]},
#  {'logn': 10,
#   'model': 'full_0.4_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010704670450245533]},
#  {'logn': 10,
#   'model': 'full_0.4_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.016849922476174794]},
#  {'logn': 11,
#   'model': 'full_0.4_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.09911864350406638]},
#  {'logn': 11,
#   'model': 'full_0.4_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.12357544094491418]},
#  {'logn': 11,
#   'model': 'full_0.4_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010498317367853454]},
#  {'logn': 11,
#   'model': 'full_0.4_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.0164047469226088]},
#  {'logn': 12,
#   'model': 'full_0.4_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.10083540459233145]},
#  {'logn': 12,
#   'model': 'full_0.4_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.1254734045283834]},
#  {'logn': 12,
#   'model': 'full_0.4_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010653774812232675]},
#  {'logn': 12,
#   'model': 'full_0.4_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.017195795505921554]},
#  {'logn': 13,
#   'model': 'full_0.4_gauss',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.10048349659468334]},
#  {'logn': 13,
#   'model': 'full_0.4_laplace',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.1251319437088754]},
#  {'logn': 13,
#   'model': 'full_0.4_singular',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.010495473538869026]},
#  {'logn': 13,
#   'model': 'full_0.4_box',
#   'cv_results': None,
#   'best_index_': 0,
#   'mean_scores': [0.016881473623586465]}]

# %% [markdown]
# ## Plot results

# %%
row_subplot_titles = [
    # "Test Score vs m", 
    # "Log10 Test Score vs m", 
    'Log10 Excess Risk vs sigma'
] #, "Train time vs n", "Predict time vs n"]

fig = make_subplots(
    rows=len(row_subplot_titles),
    cols=len(varying_variable_values),
    shared_yaxes=True,
    # subplot_titles=reduce(concat, [[f'{varying_variable}={v}' for v in varying_variable_values] for _ in row_subplot_titles]),
    subplot_titles=row_subplot_titles,
    vertical_spacing=0.1,
)

# model_names = list(model_configs.keys())
colors_list = colors.qualitative.Plotly * 4
colors_used = set()

# %%
def plot_vs_sigma(fig, results, vvv, r, c, is_better='higher', scale='log2'):
    """
    Plot Figure 2 from DnC paper
    - x-axis: sigma
    - y-axis: test score (or excess risk)
    - different lines correspond to different values of logn

    Args:
    - vvv: varying variable value
    """
    result_logn = {logn: [] for logn in range(logn_lo, logn_hi)}
    
    for result in results:
        model_name, sigma, vv_name = result["model"].split('_')

        # only select results with the correct varying variable value
        if vv_name != vvv:
            continue
        
        logn = result['logn']
        color = colors_list[logn - logn_lo]
        # print(model_name, m, f'logn: {logn}')   
        
        if scale == 'log2':
            y = np.log2(np.abs(result[f"mean_scores"]))
            hline = np.log2(np.abs(baseline_loss))

        elif scale == 'log10':
            y = np.log10(np.abs(result[f"mean_scores"]))
            hline = np.log10(np.abs(baseline_loss))

        elif scale == 'excess-log10':
            y = np.log10(np.abs(result[f"mean_scores"]) - np.abs(baseline_loss))
            hline = 0
        
        elif scale == 'excess-log2':
            y = np.log2(np.abs(result[f"mean_scores"]) - np.abs(baseline_loss))
            hline = 0

        elif scale == 'linear':
            hline = np.abs(baseline_loss)
            y = np.abs(result[f"mean_scores"])

        trace = go.Box(
            x=[float(sigma),]*len(result[f"mean_scores"]),
            y=y,
            name=f'logn={logn}',
            # opacity=0.5,
            legendgroup=str(logn),
            line_color=color,
            offsetgroup=str(logn),
            showlegend=color not in colors_used,
            boxmean=True,
        )

        fig.add_trace(trace, row=r, col=c)
        colors_used.add(color)

        result_logn[logn].append((float(sigma), np.mean(y), np.std(y)))

    # add line for baseline loss
    if 'excess' not in scale:
        fig.add_hline(
            y=hline,
            row=r, col=c, line_dash="dash",
        )

    # if c == 1: fig.update_yaxes(title_text=f"{scale}({print_name}) - {is_better} is better", row=r, col=c)
    fig.update_xaxes(title_text="m", type='linear', row=r, col=c)
    fig.update_yaxes(type='linear', row=r, col=c)
    fig.update_layout(boxmode='group')

    return result_logn

# %%
result_logn = {}
for c, vvv in enumerate(varying_variable_values):
    # plot_test_score_vs_m(str(vvv), 1, c+1, scale='linear')
    # plot_test_score_vs_m(str(vvv), 2, c+1, scale='log10')
    result_logn[vvv] = plot_vs_sigma(fig, results, str(vvv), 1, c+1, scale='excess-log2')

# %%
fig.show()

# %%
result_logn
# Out:
# {'gauss': {8: [(0.05, -10.173761492473337, 0.0),
#    (0.1, -9.596440148437656, 0.0),
#    (0.15000000000000002, -8.041990009929998, 0.0),
#    (0.2, -6.6307733948687675, 0.0),
#    (0.25, -5.527008093531952, 0.0),
#    (0.30000000000000004, -4.677241662738355, 0.0),
#    (0.35000000000000003, -4.016384702152628, 0.0),
#    (0.4, -3.493512448050078, 0.0)],
#   9: [(0.05, -10.745717896294952, 0.0),
#    (0.1, -9.755342019407195, 0.0),
#    (0.15000000000000002, -7.962514672811414, 0.0),
#    (0.2, -6.53918690924588, 0.0),
#    (0.25, -5.453772809040967, 0.0),
#    (0.30000000000000004, -4.6203344272821925, 0.0),
#    (0.35000000000000003, -3.9712957925665, 0.0),
#    (0.4, -3.4567606610976975, 0.0)],
#   10: [(0.05, -12.038445086581762, 0.0),
#    (0.1, -10.40873795072227, 0.0),
#    (0.15000000000000002, -8.243971531975179, 0.0),
#    (0.2, -6.684433878855189, 0.0),
#    (0.25, -5.537021333567144, 0.0),
#    (0.30000000000000004, -4.671566941954006, 0.0),
#    (0.35000000000000003, -4.004500620997543, 0.0),
#    (0.4, -3.479180178658005, 0.0)],
#   11: [(0.05, -12.480943770899337, 0.0),
#    (0.1, -10.773307330592253, 0.0),
#    (0.15000000000000002, -8.386830759701276, 0.0),
#    (0.2, -6.751852197711142, 0.0),
#    (0.25, -5.573715048669723, 0.0),
#    (0.30000000000000004, -4.693413207650721, 0.0),
#    (0.35000000000000003, -4.01823402165307, 0.0),
#    (0.4, -3.488128916531816, 0.0)],
#   12: [(0.05, -12.549734904678749, 0.0),
#    (0.1, -10.179306668923099, 0.0),
#    (0.15000000000000002, -8.114998349798078, 0.0),
#    (0.2, -6.609649914080455, 0.0),
#    (0.25, -5.488916598950413, 0.0),
#    (0.30000000000000004, -4.638261073891539, 0.0),
#    (0.35000000000000003, -3.980149625416561, 0.0),
#    (0.4, -3.4606014685334596, 0.0)],
#   13: [(0.05, -13.171255304130998, 0.0),
#    (0.1, -10.402575537361153, 0.0),
#    (0.15000000000000002, -8.205052916038143, 0.0),
#    (0.2, -6.655082117187255, 0.0),
#    (0.25, -5.514924697615383, 0.0),
#    (0.30000000000000004, -4.653940735602494, 0.0),
#    (0.35000000000000003, -3.9896488434248982, 0.0),
#    (0.4, -3.4662015086527878, 0.0)]},
#  'laplace': {8: [(0.05, -10.014604294409063, 0.0),
#    (0.1, -8.47790188011647, 0.0),
#    (0.15000000000000002, -6.746652595295977, 0.0),
#    (0.2, -5.540901160860513, 0.0),
#    (0.25, -4.6824691085644705, 0.0),
#    (0.30000000000000004, -4.040413570233379, 0.0),
#    (0.35000000000000003, -3.541492111230285, 0.0),
#    (0.4, -3.143304759935903, 0.0)],
#   9: [(0.05, -10.486395819459887, 0.0),
#    (0.1, -8.42796517688155, 0.0),
#    (0.15000000000000002, -6.658476992215651, 0.0),
#    (0.2, -5.470215735781782, 0.0),
#    (0.25, -4.627003504738868, 0.0),
#    (0.30000000000000004, -3.9954607140633307, 0.0),
#    (0.35000000000000003, -3.5038348090385067, 0.0),
#    (0.4, -3.110904677409588, 0.0)],
#   10: [(0.05, -11.578682058410456, 0.0),
#    (0.1, -8.777806730625834, 0.0),
#    (0.15000000000000002, -6.81084320651355, 0.0),
#    (0.2, -5.554557390424884, 0.0),
#    (0.25, -4.679954868067277, 0.0),
#    (0.30000000000000004, -4.031507709216639, 0.0),
#    (0.35000000000000003, -3.529875660575688, 0.0),
#    (0.4, -3.130615810060843, 0.0)],
#   11: [(0.05, -12.13438047223182, 0.0),
#    (0.1, -8.964069958511663, 0.0),
#    (0.15000000000000002, -6.883766763055238, 0.0),
#    (0.2, -5.592023372024279, 0.0),
#    (0.25, -4.702357893641796, 0.0),
#    (0.30000000000000004, -4.046247641766989, 0.0),
#    (0.35000000000000003, -3.5402414423520296, 0.0),
#    (0.4, -3.1382771883674057, 0.0)],
#   12: [(0.05, -11.650055066663652, 0.0),
#    (0.1, -8.632473763306132, 0.0),
#    (0.15000000000000002, -6.732276980066769, 0.0),
#    (0.2, -5.505443685635864, 0.0),
#    (0.25, -4.645745415154678, 0.0),
#    (0.30000000000000004, -4.005953014408373, 0.0),
#    (0.35000000000000003, -3.5098490942733336, 0.0),
#    (0.4, -3.1143674819750666, 0.0)],
#   13: [(0.05, -12.134179030505706, 0.0),
#    (0.1, -8.75265402752369, 0.0),
#    (0.15000000000000002, -6.782477439472922, 0.0),
#    (0.2, -5.531766927591995, 0.0),
#    (0.25, -4.661167412606425, 0.0),
#    (0.30000000000000004, -4.0156113970226, 0.0),
#    (0.35000000000000003, -3.516174905874533, 0.0),
#    (0.4, -3.118639925738899, 0.0)]},
#  'singular': {8: [(0.05, -7.884759762362965, 0.0),
#    (0.1, -8.583893017928814, 0.0),
#    (0.15000000000000002, -8.965756640131508, 0.0),
#    (0.2, -9.204818081837, 0.0),
#    (0.25, -9.347592365723221, 0.0),
#    (0.30000000000000004, -9.411379764576385, 0.0),
#    (0.35000000000000003, -9.399740658063466, 0.0),
#    (0.4, -9.315563517160214, 0.0)],
#   9: [(0.05, -8.645106931470313, 0.0),
#    (0.1, -9.303290046322743, 0.0),
#    (0.15000000000000002, -9.6852929039676, 0.0),
#    (0.2, -9.929732002278765, 0.0),
#    (0.25, -10.058784269597515, 0.0),
#    (0.30000000000000004, -10.068858650813343, 0.0),
#    (0.35000000000000003, -9.963153991729794, 0.0),
#    (0.4, -9.762745608923716, 0.0)],
#   10: [(0.05, -9.242561715433618, 0.0),
#    (0.1, -9.998560981691323, 0.0),
#    (0.15000000000000002, -10.449710792559019, 0.0),
#    (0.2, -10.737173049614885, 0.0),
#    (0.25, -10.884959740798596, 0.0),
#    (0.30000000000000004, -10.887104389538855, 0.0),
#    (0.35000000000000003, -10.740998254033522, 0.0),
#    (0.4, -10.470763662396124, 0.0)],
#   11: [(0.05, -9.874520003900347, 0.0),
#    (0.1, -10.542889729065042, 0.0),
#    (0.15000000000000002, -10.946180428207404, 0.0),
#    (0.2, -11.23898616758712, 0.0),
#    (0.25, -11.423639385644483, 0.0),
#    (0.30000000000000004, -11.453019470526355, 0.0),
#    (0.35000000000000003, -11.293954040809933, 0.0),
#    (0.4, -10.970647522406603, 0.0)],
#   12: [(0.05, -10.617321490989301, 0.0),
#    (0.1, -11.271584928516328, 0.0),
#    (0.15000000000000002, -11.581314080527623, 0.0),
#    (0.2, -11.683044114063138, 0.0),
#    (0.25, -11.601832166289478, 0.0),
#    (0.30000000000000004, -11.360077708791772, 0.0),
#    (0.35000000000000003, -11.001775723707436, 0.0),
#    (0.4, -10.578918583611296, 0.0)],
#   13: [(0.05, -11.55260255350135, 0.0),
#    (0.1, -12.187963835285979, 0.0),
#    (0.15000000000000002, -12.468225213908951, 0.0),
#    (0.2, -12.525793030356736, 0.0),
#    (0.25, -12.36277660338046, 0.0),
#    (0.30000000000000004, -12.001544335835474, 0.0),
#    (0.35000000000000003, -11.51436307829516, 0.0),
#    (0.4, -10.978904368276552, 0.0)]},
#  'box': {8: [(0.05, -8.951181344089461, 0.0),
#    (0.1, -9.566296883537246, 0.0),
#    (0.15000000000000002, -9.66602118803081, 0.0),
#    (0.2, -9.464185608073196, 0.0),
#    (0.25, -8.97984168088308, 0.0),
#    (0.30000000000000004, -8.340698097565497, 0.0),
#    (0.35000000000000003, -7.6826264773643, 0.0),
#    (0.4, -7.051535431327862, 0.0)],
#   9: [(0.05, -9.64874091705391, 0.0),
#    (0.1, -10.293415977730948, 0.0),
#    (0.15000000000000002, -10.338402854570054, 0.0),
#    (0.2, -9.890755025481804, 0.0),
#    (0.25, -9.146647764775333, 0.0),
#    (0.30000000000000004, -8.374834694225454, 0.0),
#    (0.35000000000000003, -7.651285263153372, 0.0),
#    (0.4, -7.001068442023172, 0.0)],
#   10: [(0.05, -10.448299829824714, 0.0),
#    (0.1, -11.213516591461396, 0.0),
#    (0.15000000000000002, -11.223742721405522, 0.0),
#    (0.2, -10.536213858587848, 0.0),
#    (0.25, -9.621837752415711, 0.0),
#    (0.30000000000000004, -8.716402505790011, 0.0),
#    (0.35000000000000003, -7.904112055119661, 0.0),
#    (0.4, -7.189696624161341, 0.0)],
#   11: [(0.05, -10.945986493643794, 0.0),
#    (0.1, -11.634511597249977, 0.0),
#    (0.15000000000000002, -11.763313530351667, 0.0),
#    (0.2, -11.042046187681985, 0.0),
#    (0.25, -9.946538436152865, 0.0),
#    (0.30000000000000004, -8.921628925565372, 0.0),
#    (0.35000000000000003, -8.040717014835828, 0.0),
#    (0.4, -7.286642719670607, 0.0)],
#   12: [(0.05, -11.691307588520703, 0.0),
#    (0.1, -11.98109665345047, 0.0),
#    (0.15000000000000002, -11.447835576718964, 0.0),
#    (0.2, -10.507747106940387, 0.0),
#    (0.25, -9.517461117180257, 0.0),
#    (0.30000000000000004, -8.613102024413244, 0.0),
#    (0.35000000000000003, -7.816351290738248, 0.0),
#    (0.4, -7.118630096792104, 0.0)],
#   13: [(0.05, -12.577396490007862, 0.0),
#    (0.1, -12.758816543171003, 0.0),
#    (0.15000000000000002, -12.011619545943867, 0.0),
#    (0.2, -10.853328166494169, 0.0),
#    (0.25, -9.724896488760399, 0.0),
#    (0.30000000000000004, -8.744719815276571, 0.0),
#    (0.35000000000000003, -7.906092216018504, 0.0),
#    (0.4, -7.183066742730273, 0.0)]}}

# %%
fig = make_subplots(
    rows=1, 
    cols=len(varying_variable_values), 
    shared_yaxes=True,
    subplot_titles=[f'{varying_variable}={vvv}' for vvv in varying_variable_values],
)
colors_used = set()

for c, vvv in enumerate(varying_variable_values):
    for logn, result in result_logn[vvv].items():
        x,y, y_std = zip(*result_logn[vvv][logn])
        color = colors_list[logn - logn_lo]

        fig.add_trace(go.Scatter(
            # x=np.log2(x) / logn, 
            x=x,
            y=y, 
            mode='lines+markers', 
            name=f'N={2**logn}', 
            error_y=dict(
                type='data', 
                array=y_std, 
                visible=True
            ),
            line=dict(
                width=1,
                color=colors_list[logn - logn_lo],
                dash='solid',
            ),
            legendgroup=str(logn),
            showlegend=color not in colors_used,
        ), row=1, col=c+1)
        colors_used.add(color)

    if c==0: fig.update_yaxes(title_text="log2(Excess Risk)", row=1, col=c+1)
# for logn, result in result_logn.items():
#     x,y, y_std = zip(*kt_result_logn[logn])
#     fig.add_trace(go.Scatter(
#         x=x, 
#         y=y, 
#         mode='lines+markers', 
#         name=f'N={2**logn}', 
#         error_y=dict(
#             type='data', 
#             array=y_std, 
#             visible=True
#         ),
#         line=dict(
#             width=1,
#             color=colors_list[logn - logn_lo],
#             dash='dot',
#         ),
#         legendgroup=str(logn),
#     ))

# update x axis title
fig.update_xaxes(title_text="h")
# fig.update_layout(title=f'Figure 2: f={f_name}(sigma={noise})')
fig.update_layout(title=f'Figure 2: f={f_name}(k={k}, noise={noise}) - Full')
fig.show()
